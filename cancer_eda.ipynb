# %% [markdown]
# # Задание №1. EDA данных cancer.csv
#
# Проведите простейший анализ данных предложенного датасета:
# 1. Выведите количество строк с пропущенными значениями. Удалите их.
# 2. Выведите количество дублированных строк. Оставьте только оригинальные строки.
# 3. В одной из строк допущена ошибка в одном из признаков. Найдите эту строку, предположите, какая ошибка была допущена, и исправьте.
# 4. Найдите признак(и) с наибольшим разбросом.
#
# Данные представляют собой измерения раковых и здоровых клеток. Целевая переменная - label.

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# Путь к файлу cancer.csv
CANCER_DATASET_PATH = "/home/nina-lukashina/work/teaching/2020_spring_bioinf_final/1/HWs/cancer.csv"

# %%
df = pd.read_csv(CANCER_DATASET_PATH)
df.head()
# Out:
#   label      1      2       3       4        5        6       7        8  \
# 0     M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.3001  0.14710
# 1     M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869  0.07017
# 2     M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974  0.12790
# 3     M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414  0.10520
# 4     M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980  0.10430
#
#         9  ...     21     22      23      24      25      26      27      28  \
# 0  0.2419  ...  25.38  17.33  184.60  2019.0  0.1622  0.6656  0.7119  0.2654
# 1  0.1812  ...  24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416  0.1860
# 2  0.2069  ...  23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504  0.2430
# 3  0.2597  ...  14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869  0.2575
# 4  0.1809  ...  22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000  0.1625
#
#        29       30
# 0  0.4601  0.11890
# 1  0.2750  0.08902
# ...

# %%
na_row1 = df.loc[3, :].copy()
na_row1[12] = np.nan
na_row2 = df.loc[150, :].copy()
na_row2[25] = np.nan
new_df = df.append([na_row1, na_row2])
new_df = new_df.reset_index(drop=True)
new_df
# Out:
#     label      1      2       3       4        5        6        7        8  \
# 0       M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.30010  0.14710
# 1       M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.08690  0.07017
# 2       M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.19740  0.12790
# 3       M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.24140  0.10520
# 4       M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.19800  0.10430
# ..    ...    ...    ...     ...     ...      ...      ...      ...      ...
# 566     M  16.60  28.08  108.30   858.1  0.08455  0.10230  0.09251  0.05302
# 567     M  20.60  29.33  140.10  1265.0  0.11780  0.27700  0.35140  0.15200
# 568     B   7.76  24.54   47.92   181.0  0.05263  0.04362  0.00000  0.00000
# 569     M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.24140  0.10520
# 570     B  13.00  20.78   83.51   519.4  0.11350  0.07589  0.03136  0.02645
#
# ...

# %%
new_df = df.append([df.loc[25, :].copy(), df.loc[25, :].copy(), df.loc[566, :].copy(), df.loc[38, :].copy()])
new_df = new_df.reset_index(drop=True)
new_df
# Out:
#     label      1      2       3       4        5        6        7        8  \
# 0       M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.30010  0.14710
# 1       M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.08690  0.07017
# 2       M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.19740  0.12790
# 3       M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.24140  0.10520
# 4       M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.19800  0.10430
# ..    ...    ...    ...     ...     ...      ...      ...      ...      ...
# 568     B   7.76  24.54   47.92   181.0  0.05263  0.04362  0.00000  0.00000
# 569     M  17.14  16.40  116.00   912.7  0.11860  0.22760  0.22290  0.14010
# 570     M  17.14  16.40  116.00   912.7  0.11860  0.22760  0.22290  0.14010
# 571     M  16.60  28.08  108.30   858.1  0.08455  0.10230  0.09251  0.05302
# 572     M  14.99  25.20   95.54   698.8  0.09387  0.05131  0.02398  0.02899
#
# ...

# %%
new_df.loc[33, "26"] = new_df.loc[33, "26"] * 100.0
sns.distplot(new_df.loc[:, "26"])

# %%
new_df.describe()
# Out:
#                 1           2           3            4           5  \
# count  573.000000  573.000000  573.000000   573.000000  573.000000
# mean    14.143628   19.305218   92.087644   656.220244    0.096413
# std      3.517888    4.312152   24.265308   351.117794    0.014085
# min      6.981000    9.710000   43.790000   143.500000    0.052630
# 25%     11.710000   16.180000   75.210000   420.300000    0.086370
# 50%     13.400000   18.840000   86.490000   552.400000    0.095870
# 75%     16.020000   21.810000  104.700000   793.200000    0.105400
# max     28.110000   39.280000  188.500000  2501.000000    0.163400
#
#                 6           7           8           9          10  ...  \
# count  573.000000  573.000000  573.000000  573.000000  573.000000  ...
# mean     0.104675    0.089161    0.049210    0.181509    0.062813  ...
# std      0.053175    0.079881    0.039049    0.028299    0.007080  ...
# min      0.019380    0.000000    0.000000    0.106000    0.049960  ...
# ...

# %%
new_df.to_csv("/home/nina-lukashina/work/teaching/2020_spring_bioinf_final/1/HWs/cancer_eda.csv", index=False)

# %%
pd.read_csv("/home/nina-lukashina/work/teaching/2020_spring_bioinf_final/1/HWs/cancer_eda.csv")

# %%
new_df.dropna().drop_duplicates()
# Out:
#     label      1      2       3       4        5        6        7        8  \
# 0       M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.30010  0.14710
# 1       M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.08690  0.07017
# 2       M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.19740  0.12790
# 3       M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.24140  0.10520
# 4       M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.19800  0.10430
# ..    ...    ...    ...     ...     ...      ...      ...      ...      ...
# 564     M  21.56  22.39  142.00  1479.0  0.11100  0.11590  0.24390  0.13890
# 565     M  20.13  28.25  131.20  1261.0  0.09780  0.10340  0.14400  0.09791
# 566     M  16.60  28.08  108.30   858.1  0.08455  0.10230  0.09251  0.05302
# 567     M  20.60  29.33  140.10  1265.0  0.11780  0.27700  0.35140  0.15200
# 568     B   7.76  24.54   47.92   181.0  0.05263  0.04362  0.00000  0.00000
#
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaled_df = pd.DataFrame(scaler.fit_transform(df.loc[:, "1":"30"]))
scaled_df.describe()
# Out:
#                0           1           2           3           4           5   \
# count  569.000000  569.000000  569.000000  569.000000  569.000000  569.000000
# mean     0.338222    0.323965    0.332935    0.216920    0.394785    0.260601
# std      0.166787    0.145453    0.167915    0.149274    0.126967    0.161992
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.223342    0.218465    0.216847    0.117413    0.304595    0.139685
# 50%      0.302381    0.308759    0.293345    0.172895    0.390358    0.224679
# 75%      0.416442    0.408860    0.416765    0.271135    0.475490    0.340531
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#                6           7           8           9   ...          20  \
# count  569.000000  569.000000  569.000000  569.000000  ...  569.000000
# mean     0.208058    0.243137    0.379605    0.270379  ...    0.296663
# ...
